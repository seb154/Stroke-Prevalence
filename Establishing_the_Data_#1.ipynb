# %% [markdown]
# # Exploring the Data

# %% [markdown]
# ## (1)

# %%
import pandas as pd

df = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %% [markdown]
# ## (2)

# %% [markdown]
# The dataset is publicly available on Kaggle. It is named "Stroke Prediction Dataset" by fedesoriano, who is a data scientist at Kaggle. Users can access the data by downloading the CSV file.

# %% [markdown]
# ## (3)

# %% [markdown]
# According to the dataset description, the data is from a confidential healthcare source and was compiled to reflect patient-level health indicators related to stroke occurrence. It also states to "use only for educational purposes". The author of this dataset is Federico Soriano, a data scientist located in Madrid. The dataset includes demographic information, medical history, and lifestyle-related variables.

# %% [markdown]
# ## (4)

# %% [markdown]
# Each row in the dataset represents an individual patient. The columns capture demographic, medical, and lifestyle-related information relevant to stroke prediction.

# %%
col_names = pd.DataFrame({"Column Names": df.columns})
# Out:
#          Column Names
# 0                  id
# 1              gender
# 2                 age
# 3        hypertension
# 4       heart_disease
# 5        ever_married
# 6           work_type
# 7      Residence_type
# 8   avg_glucose_level
# 9                 bmi
# 10     smoking_status
# 11             stroke

# %%
cols_table = pd.DataFrame({
    "Column Name": df.columns,
    "Meaning": [
        "Unique identifier for each patient",
        "Gender of the patient",
        "Age of the patient",
        "Hypertension status (1 = Yes, 0 = No)",
        "Heart disease status (1 = Yes, 0 = No)",
        "Whether the patient has ever been married",
        "Type of employment",
        "Type of residence (Urban or Rural)",
        "Average glucose level",
        "Body Mass Index (BMI)",
        "Smoking history",
        "Stroke occurrence (1 = Yes, 0 = No)"
    ],
    "Data Type": [
        "Numeric",
        "Categorical",
        "Numeric",
        "Binary",
        "Binary",
        "Categorical",
        "Categorical",
        "Categorical",
        "Numeric",
        "Numeric",
        "Categorical",
        "Binary"
    ]
})

cols_table
cols_table.style.set_caption("Table 1: Dataset Features and Descriptions")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c16a9">
#   <caption>Table 1: Dataset Features and Descriptions</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c16a9_level0_col0" class="col_heading level0 col0" >Column Name</th>
#       <th id="T_c16a9_level0_col1" class="col_heading level0 col1" >Meaning</th>
#       <th id="T_c16a9_level0_col2" class="col_heading level0 col2" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c16a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c16a9_row0_col0" class="data row0 col0" >id</td>
#       <td id="T_c16a9_row0_col1" class="data row0 col1" >Unique identifier for each patient</td>
#       <td id="T_c16a9_row0_col2" class="data row0 col2" >Numeric</td>
#     </tr>
#     <tr>
#       <th id="T_c16a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c16a9_row1_col0" class="data row1 col0" >gender</td>
# ...
